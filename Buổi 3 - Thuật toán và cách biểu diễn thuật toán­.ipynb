# %% [markdown]
# # Thuật toán và cách biểu diễn thuật toán
#
# ### Lập trình
#
# Lập trình là gì?

# %% [markdown]
# Lập trình là đưa ra những câu lệnh để máy tính thực hiện.
#
# Đưa ra câu lệnh A, trước câu lệnh B thì câu lệnh A sẽ được thực hiện trước.

# %% [markdown]
# ### Thuật toán
#
# Thuật toán là gì?

# %% [markdown]
# Thuật toán là những câu lệnh được đưa ra để giải quyết một vấn đề nào đó.

# %% [markdown]
# ### Mã gỉả
#
# #### Khái niệm:
#
# Mã giả được viết với ngôn ngữ tự nhiên một thuật toán nào đó dùng để giải quyết một vấn đề lập trình.
#
# Mã giả được quy ước chung theo từng nơi làm việc.
#
# Ví dụ:
#
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Khi ta đói và thèm một món nào đó (nhập từ bàn phím), tiến hành đặt đồ ăn, nếu món ta thèm còn thì đặt đồ món đó, không còn thì đặt cơm sườn, không còn cơm sườn thì đi ngủ.
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (món ăn)
# Nếu (món ăn còn):
#     Đặt (món ăn)
# Ngược lại:
#     Nếu (cơm sườn còn):
#         Đặt (cơm sườn)
#     Ngược lại:
#         Đi ngủ

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số đó có phải là số lớn hơn 10 không.
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (a)
# Nếu (a>10):
#     in ra ('a là số lớn hơn 10')
# Ngược lại:
#     in ra ('a là số không lớn hơn 10')

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số a là số âm hay số dương hay là số 0
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (a)
# Nếu (a>0):
#     in ra ('a là số dương')
# Ngược lại:
#     Nếu (a<0):
#         in ra ('a là số âm')
#     Ngược lại:
#         in ra ('a là số 0')

# %% [markdown]
# ### Lưu đồ giải thuật
#
# Lưu đồ giải thuật là một thuật toán được biểu diễn với dạng lưu đồ
#
# Công cụ vẽ lưu đồ giải thuật: https://draw.io/
#
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Khi ta đói và thèm một món nào đó (nhập từ bàn phím), tiến hành đặt đồ ăn, nếu món ta thèm còn thì đặt đồ món đó, không còn thì đặt cơm sườn, không còn cơm sườn thì đi ngủ.
#
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Ảnh chụp Màn hình 2024-07-02 lúc 7.55.49 CH.png](attachment:f102b3c8-fe36-4828-9480-771b9cc5cae7.png)

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số đó có phải là số lớn hơn 10 không.
#
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Ảnh chụp Màn hình 2024-07-02 lúc 8.06.05 CH.png](attachment:eb5a7929-4c39-4782-b215-3eee8fae4c8e.png)

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số a là số âm hay số dương
#
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ### Bài tập
#
# <b>Đề bài</b>
#
# Nhập vào nhiệt độ C, chuyển sang độ F rồi in ra màn hình
#
# <b>Mã giả:</b>

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Ảnh chụp Màn hình 2024-07-02 lúc 8.06.53 CH.png](attachment:15fedbc9-4879-40ad-91b6-60db12437abd.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào lương tháng này, nếu lương tháng này nhiều hơn 2 triệu thì trừ đi 10% thuế, nếu không thì không trừ.
#
# Hãy tính và in ra lương thực nhận được
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (lương)
# Nếu (lương>2 triệu):
#     Thực nhận = lương tháng này*0,9
# In (Thực nhận)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Ảnh chụp Màn hình 2024-07-02 lúc 8.19.45 CH.png](attachment:951accd3-4f15-487a-a538-cde5014aecf1.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào lương thực nhận được tháng này, nếu lương ít hơn 10 triệu, đưa hết cho vợ, nếu lương nhiều hơn 10 triệu, vợ cho 10% lương
#
# Hãy tính và in ra màn hình phần lương mình được nhận
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (lương)
# Nếu (lương <= 10 triệu):
#     Thực nhận = 0
# Ngược lại:
#     Thực nhận = lương*0.1

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Ảnh chụp Màn hình 2024-07-02 lúc 8.41.44 CH.png](attachment:e1034b3a-f1c2-408f-85f3-65676841431f.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào số điểm văn và điểm toán, tính và in ra điểm trung bình, nếu điểm trung bình lớn hơn 8 thì in ra dòng chữ Học sinh giỏi, ngược lại thì in ra dòng chữ Không phải học sinh giỏi
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (điểm văn, điểm toán)
# In (điểm tb =(văn + toán)/2)
# Nếu (điểm tb >8):
#     In (Học sinh giỏi)
# Ngược lại:
#     In (Không phải học sinh giỏi)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Ảnh chụp Màn hình 2024-07-02 lúc 8.51.43 CH.png](attachment:b8e84de5-0fe5-4f5b-9175-09d3a78486c6.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào một số, kiểm tra xem số đó có chia hết cho 5 hay không
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập a
# Số dư = a%5
# Nếu (Số dư==0):
#     In (a chia hết cho 5)
# Ngược lại:
#     In (a không chia hết cho 5)
#
# Note:   % chia lấy phần dư
#         // chia lấy phần nguyên

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Ảnh chụp Màn hình 2024-07-02 lúc 9.11.17 CH.png](attachment:f17287fd-2912-4103-9f6f-35e9e559a51a.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào điểm số, nếu điểm số lớn hơn hoặc bằng 8, in ra dòng chữ Học sinh giỏi, nếu điểm số bé hơn 8 và lớn hơn hoặc bằng 6, in ra dòng chữ chữ học sinh Khá, ngược lại in ra dòng chữ Học sinh trung bình
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (điểm)
# Nếu (điểm >=8):
#     In (Học sinh giỏi)
# Ngược lại:
#     Nếu (điểm <6):
#         In (Học sinh trung bình)
#     Ngược lại:
#         In (Học sinh Khá)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Ảnh chụp Màn hình 2024-07-02 lúc 9.20.44 CH.png](attachment:228400fc-7463-4eab-b24e-e2dca7370c63.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào một số, kiểm tra tính chẳn lẻ và số đó có lớn hơn 10 hay không. (in ra 4 trường hợp: chẳn lớn hơn 10, lẻ lớn hơn 10, chẳn bé hơn hoặc bằng 10, lẻ bé hơn 10)
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (số a)
# Số dư = a%2
# Nếu (dư=0):
#     Nếu a>10
#         In (a là số chẵn và lớn hơn 10)
#     Ngược lại:
#         In (a là số chẵn và nhỏ hơn hoặc bằng 10)
# Ngược lại:
#     Nếu a>10:
#         In (a là số lẻ và lớn hơn 10)
#     Ngược lại:
#         In (a là số lẻ và nhỏ hơn hoặc bằng 10)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>
